# %%
import pandas as pd
import numpy as np
df = pd.read_csv("dataset/train.csv")

# %%
df.gender.value_counts()
# Out:
# F          18490
# M          18443
# Unknown       59
# Name: gender, dtype: int64

# %%
import seaborn as sns

# %%
sns.distplot(df['region_category'].value_counts(),bins=3)

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['customer_id', 'Name', 'age', 'gender', 'security_no',
#        'region_category', 'membership_category', 'joining_date',
#        'joined_through_referral', 'referral_id', 'preferred_offer_types',
#        'medium_of_operation', 'internet_option', 'last_visit_time',
#        'days_since_last_login', 'avg_time_spent', 'avg_transaction_value',
#        'avg_frequency_login_days', 'points_in_wallet', 'used_special_discount',
#        'offer_application_preference', 'past_complaint', 'complaint_status',
#        'feedback', 'churn_risk_score'],
#       dtype='object')

# %%
sns.barplot(x = df['gender'], y = df['churn_risk_score'])

# %%
df["gender"] = df["gender"].replace("Unknown",np.NaN)
df["gender"].fillna(df["gender"].value_counts().index[0],inplace=True)

# %%
sns.barplot(x = df['gender'], y = df['churn_risk_score'].sum())

# %%
sns.barplot(x = df['region_category'], y = df['churn_risk_score'].mean())

# %%
df['region_category'].isnull().sum()
# Out:
# 5428

# %%
df['region_category'].fillna(df["region_category"].value_counts().index[0],inplace=True)

# %%
df["region_category"].value_counts().index[0]
# Out:
# 'Town'

# %%
sns.barplot(x = df['region_category'], y = df['churn_risk_score'].sum())

# %%
sns.barplot(x = df['medium_of_operation'], y = df['churn_risk_score'].mean())

# %%
df['medium_of_operation'] = df['medium_of_operation'].replace("?",np.NaN)
df['medium_of_operation'].fillna(df["medium_of_operation"].value_counts().index[0],inplace=True)

# %%
sns.barplot(x = df['medium_of_operation'], y = df['churn_risk_score'].mean())

# %%
test = pd.read_csv("dataset/test.csv")

# %%
test["days_since_last_login"]
# Out:
# 0         12
# 1         11
# 2         18
# 3       -999
# 4          6
#         ...
# 19914     16
# 19915     21
# 19916     18
# 19917      3
# 19918      8
# Name: days_since_last_login, Length: 19919, dtype: int64

# %%
train = pd.read_csv("dataset/train.csv")

# %%
test["days_since_last_login"] = test["days_since_last_login"].replace(-999,50)
sns.distplot(test["days_since_last_login"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-61489c6c2565> in <module>
#       1 test["days_since_last_login"] = test["days_since_last_login"].replace(-999,50)
# ----> 2 sns.distplot(train["days_since_last_login"],hue=train["churn_risk_score"])
#
# TypeError: distplot() got an unexpected keyword argument 'hue'

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df = df.astype(str).apply(le.fit_transform)

# %%
sns.heatmap(df.corr(), annot = True, cmap = 'viridis')
